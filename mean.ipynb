# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
X = np.arange(-3,6).astype("float32").reshape(-1,1)
X = np.vstack([X,20])
print(X.reshape)
print(X)
# Out:
# <built-in method reshape of numpy.ndarray object at 0x00000283FFA1E7F0>
# [[-3.]
#  [-2.]
#  [-1.]
#  [ 0.]
#  [ 1.]
#  [ 2.]
#  [ 3.]
#  [ 4.]
#  [ 5.]
#  [20.]]

# %%
X_simple = X/X.max()
X_simple
# Out:
# array([[-0.15],
#        [-0.1 ],
#        [-0.05],
#        [ 0.  ],
#        [ 0.05],
#        [ 0.1 ],
#        [ 0.15],
#        [ 0.2 ],
#        [ 0.25],
#        [ 1.  ]])

# %%
X_minmax = (X - X.min()) /(X.max() - X.min())
X_minmax
# Out:
# array([[0.        ],
#        [0.04347826],
#        [0.08695652],
#        [0.13043478],
#        [0.17391304],
#        [0.2173913 ],
#        [0.26086957],
#        [0.30434783],
#        [0.34782609],
#        [1.        ]])

# %%
sc = MinMaxScaler()
X_minmax2 = sc.fit_transform(X)#X_minmax

# %%
X_Standard = (X - X.min())/X.std()
X_Standard
# Out:
# array([[0.        ],
#        [0.16118553],
#        [0.32237105],
#        [0.48355658],
#        [0.64474211],
#        [0.80592764],
#        [0.96711316],
#        [1.12829869],
#        [1.28948422],
#        [3.70726713]])

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
plt.hist(X, bins=50);
plt.title('original data')

plt.subplot(1,2,2)
plt.hist(X_simple, bins=50)
plt.title('simple scaling')
# Out:
# Text(0.5, 1.0, 'simple scaling')

# %%
plt.figure(figsize = (14,4))
plt.subplot(1,2,1)
plt.hist(X, bins=50)
plt.title('Original Data')
# Out:
# Text(0.5, 1.0, 'Original Data')
